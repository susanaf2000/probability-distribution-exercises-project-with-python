# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0) #k being the given value when calling the function with parameters size (nb of trials) and prob (prob of success in each trial)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial.
import numpy as np
np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

data = rbinom(1000, size = 20, prob = 0.5)



# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %%
# TODO

from scipy.stats import norm

# Define all the probability functions related to this distribution

def dnorm(x, median=0, sigma=1):
    """
    Calculates the point estimate of the normal distribution
    """
    result = norm.pdf(x, loc=median, scale=sigma) #k being the given value when calling the function with parameters size (nb of trials) and prob (prob of success in each trial)

    return result

def pnorm(x, median=0, sigma=1):
    """
    Calculates the cumulative of the normal distribution
    """
    result = norm.cdf(x, loc=median, scale=sigma)

    return result

def qnorm(p, median=0, sigma=1):
    """
    Calculates the quantile function from the normal distribution
    """
    result = norm.ppf(q = p, loc=median, scale=sigma)

    return result

def rnorm(n, median, sigma):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(loc= median, scale=sigma, size=n)

    return result

# %%
# normal(0, 1) distribution where median = 0 and std deviation = 1
import numpy as np

np.random.seed(42)

print(f"Probability that a Normal(0, 1) takes the value 2: {dnorm(2, median = 10, sigma = 1)}")
print(f"Probability that a Normal(0, 1) will take a value less than 2: {pnorm(2, median = 10, sigma = 1)}")
print(f"Which value of a Normal(0, 1) has a cumulative probability of 0.9? {qnorm(0.9, median = 10, sigma = 1)}")
print(f"Generate 2000 random values from a Normal(0, 1) distribution: {rnorm(2000, median = 10, sigma = 1)}")
# Out:
# Probability that a Normal(0, 1) takes the value 2: 5.052271083536893e-15
# Probability that a Normal(0, 1) will take a value less than 2: 6.22096057427174e-16
# Which value of a Normal(0, 1) has a cumulative probability of 0.9? 11.2815515655446
# Generate 2000 random values from a Normal(0, 1) distribution: [10.49671415  9.8617357  10.64768854 ...  9.11812535  9.83693304
#   9.25509736]

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

#median = 0 --> only need to write it if different than the default value to then use it when calling the function
#sigma = 1

data = rnorm(2000, median = 0, sigma = 1)

pdf = dnorm(data) #we call the function created before with the arguments and parameters needed knowing that the argument takes a given value
cdf = pnorm(data) #if we don't write the parameters, it will have the default parameters given to the function
ppf = qnorm(data) #we only need to write the parameters if we want to change from the default 

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pdf, "r-") #stem is what creates the lollipop plot and gices utomatically the x-axis (-4,4) according with the data provided when we don't specify the x-axis
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt


p = np.linspace(0,1)


def duniform(x, mean=0, sigma=1):
    """
    Calculates the point estimate of the normal distribution
    """
    result = norm.pdf(x=x, loc=mean, scale=sigma) #k being the given value when calling the function with parameters size (nb of trials) and prob (prob of success in each trial)

    return result

def puniform(x, mean=0, sigma=1):
    """
    Calculates the cumulative of the normal distribution
    """
    result = norm.cdf(x=x, loc=mean, scale=sigma)

    return result

def quniform(x, mean=0, sigma=1):
    """
    Calculates the quantile function from the normal distribution
    """
    result = norm.ppf(q=x, loc=mean, scale=sigma)

    return result

def runiform(mean, sigma, n):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(loc= mean, scale=sigma, size=n)

    return result

# %%
from scipy.stats import uniform
import numpy as np

np.random.seed(42)

# Parameters for the uniform distribution
start = 0
end = 1

# Probability density function (PDF) at value 0.5
print(f"Probability Density Function (PDF) at value 0.5: {duniform(0.5, mean=start, sigma=end-start)}")

# Cumulative distribution function (CDF) at value 0.5
print(f"Cumulative Distribution Function (CDF) at value 0.5: {puniform(0.5, mean=start, sigma=end-start)}")

# Value of the uniform distribution at cumulative probability 0.9
print(f"Value of the distribution at cumulative probability 0.9: {quniform(0.9, mean=start, sigma=end-start)}")

# Generate 2000 random values from the uniform distribution
print(f"Generated 2000 random values from the uniform distribution: {runiform(mean=start, sigma=end-start, n=2000)}")
# Out:
# Probability Density Function (PDF) at value 0.5: 0.3520653267642995
# Cumulative Distribution Function (CDF) at value 0.5: 0.6914624612740131
# Value of the distribution at cumulative probability 0.9: 1.2815515655446004
# Generated 2000 random values from the uniform distribution: [ 0.49671415 -0.1382643   0.64768854 ... -0.88187465 -0.16306696
#  -0.74490264]

# %%
from scipy.stats import uniform
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

#Plotting the data
data = np.linspace(0, 1, 1000)  


# PDF, CDF, and PPF for a uniform distribution between 0 and 1
pdf = duniform(data)
cdf = quniform(data)
ppf = puniform(data)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(data, pdf, "r-") #stem is what creates the lollipop plot and gices utomatically the x-axis (-4,4) according with the data provided when we don't specify the x-axis
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, ppf, "g-")

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
